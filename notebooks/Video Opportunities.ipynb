# %% [markdown]
# ## Video Opportunities: each notebook 10-20 min of video

# %% [markdown]
# Introduction:
#
#     - purpose of the course
#     - summary of the story we'll tell
#     - what we're doing, why, and how
#
#    * we need to think carefully about defining an overarching question that will guide our course
#
#    * we should also talk in overview about data frames, RDMS, databases, python, etc.

# %% [markdown]
# Part I: Loading Data
#
#     Q: What kind of data are we looking for?
#     A: Flu statistics. Who is getting the flu, where, when and what kind?
#
#     Q: Where might we find this data?
#     A: CDC, WHO, HHS, OIE
#
# Notebook 1: Loading and Sharing Simple CSV Data
#     - What data is in this file?
#         -- mappings of states to their populations and flu surveillance regions, ????
#     - How do we plan on using this data?
#     - Overview of loading a CSV file
#         -- what's the file type? what tools?
#         -- process overview: import, parse file, convert, write to DB
#     - Putting stuff into the DB (cursors, tables, etc.)
#
# Notebook 2: Loading Simple Delimited Data
#     - What data is in this file?
#             -- country-level data for influenza surveillance: what  strain, how many samples, etc.
#     - How are we going to split this data?
#     - What does it mean to put the data into tables in the DB?
#     - What's a view?
#
# Notebook 3: Loading HHS Flu Vaccination JSON Data
#     - What data is in this file?
#     - What is JSON? Why do people use it?
#
# Notebook 4: Gathering OIE Pathogenic Flu Data from the Web
#     - What data is in this file?
#         -- pathogenic straings of influenza in animals
#     - Pythonic tools --> what are they? why?
#     - Extracting useful data from HTML pages
#     - Dealing with inconsistencies in the data
#
#    * are we interested in combining these first few notebooks into one video since they are simpler in content?

# %% [markdown]
# Part II: Analyzing and Visualizing Data with Databases
#
#     Q: Now that we have some data, what's our next step?
#     A: One next step is to use our data to give visual answers to our questions. In this next part, we'll ask four broad questions about the flu and use different data visualization tools to test hypotheses, and then visualize the results.
#
# Notebook 1: Does Ethnicity Impact Vaccination Rates?
#     - What is hypothesis testing? Overview of formulating a testable hypothesis
#     - T-tests (**** Is this one or two tailed?)
#     - Conclusions --> only group that did not differ is African-American vs. Hispanic (**** Do we want to speculate on more conclusions about this?)
#
# Notebook 2: Do Vaccination Rates Impact Flu Rates?
#     - Analytical SQL? Ordinary Least Squares regression models? Why?
#     - What's statsmodel Python library? Why are we using it?
#     - What manipulations do we need to do to the data to get it to something we can analyze?
#     - Why should we "start by taking a look at it?" Shouldn't we have a hypothesis first?
#         -- Using linear models when results aren't obvious visually
#     - Why our linear model isn't working
#         -- what is this "print shot_to_sick_model.summary()" business? nonrobust?
#     - New model explanation; theories about why it's better; checking goodness of fit
#     - Summary + food for thought
#
#  * yikes to "year-over-year change in flu is CAUSED" ... we always learned to be about making claims about causation --> correlation does not imply causation
#
# Notebook 3: Does GDP explain flu rates?
#     - What's the difference between per capita and total GDP? Why might wealthier countries ahve lower rates of infection?
#     - What's a linear model and why is it a good way to answer this question? Correlation between GDP and flu rates? Whats a linear correlation? What's a linear regression model and why would knowing about linear correlation help us decide if it's an appropriate model?
#     - Results of type-A and type-B regressions, next steps?
#     - Speculations on minor effect of GDP on the flu?
#
# Notebook 4: Does Living in Cities Influence Flu Rates?
#  * is it fair to generalize a country as "largely urban" or "largely agrarian"?
#      - Explanation of analysis 'per capita'
#      - Quick scatter plot to look for obvious relationships --> why do this before forming a hypothesis? How is poking around different from hypothesis testing? How are they related?
#      - Results table: p value vs r-squared
#      - Set of residual plots
#          - "Notice that as urban population percentage increases, the model explains fewer of the data points" ** this conclusion needs more explanation, it's not clear
#      - A follow-up approach: population and GDP
#          - Two-factor linear models
#          - Results explain almost 20% more of the data
#          - Interaction plot
#
#  * more rhetorical questions in the notebooks
#  * factor interaction and residual plotting needs more explanation in general, it's not obvious
#
# Notebook 5: How Do Sanitation a
# nd Clean Water Effect Flu Transmission?
#     - Thinking about other factors that effect our health: sanitation + clean water
#     - Where/what data can we get to look at this?
#     - Hypothesis: compare improvements in sanitation to flu cases
#     - What does cellular phone access and primary education have to do with anything?
#     - Modeling data in parallel
#     - Are there noticable differences in sanitation across the WHO regions?
#     - What are our factors of interest?
#     - Follow-up: modeling the AFRO region
#     - Handling sample size
#     - Binary vs. linear effects; logistic regression model; testing and training sets
#     - Actual classification of the training set? (the graph is confusing)
#     - Predictions: **** this whole section of the notebook is confusing
#     - Handling an inconclusive analysis

# %% [markdown]
# Part III: Analyzing Big Data with Apache Spark
#
# Introduction:
#     - What is...
#         - Big Data?
#         - Apache Spark?
#         - Apache Hadoop?
#
# Notebook 1: Basic Big Data Manipulation with PySpark
#     - Loading data into a Hadoop file system
#     - What's an RDD? Explain the Spark Context
#     - What data are we going to work with now? What kinds of 'big data' would help us with our flu investigation?
#     - What news stories mention the flu? What are the stories that mention the flu about? How could we go about finding out? What's wrong with our first-pass method?
#
# Notebook 2: Moving and Clustering Data with Sqoop and Spark
# 	- flu types a + b (http://www.cdc.gov/flu/about/viruses/types.htm)
# 	- integrating sql
# 	- deciding how many clusters with k means (within set sum of squared error, elbow in the graph, point of diminishing returns)
# 	- flatten_cluster_data
# 	- how good is the flu reporting? how large is the population?
#
# Notebook 3: Finding Important Words with Spark
#     - Guiding questions: How do we figure out what articles are "about"? How important is news about the flu over time?
#     - TF-IDF transformation
#     - Cleaning and normalizing the text
#     - PairRDD
#     - Scale term frequency by how common that word is across all docs
#     - Reframing the problem: Why would we want to know about importance over time? Is there a flu season?
#     - Incorporating all the data
#     - Real trends
#
#  * Is it robust to consider words inside of date ranges without considering them inside of articles?
#
#  * I think this notebook needs more explanation
#
# Notebook 4: Building a Trend Search with Big Data and Big Data SQL
#     - Preliminary question unclear -- does the flu impact the news?
#     - Pairing term-trend data with statistics data
#     - Big Data SQL, what is it and how is it different from what we just did with batch-based copies in Hadoop
#     - First-pass comparison
#     - No correlated rise between H5N1 and countries with the most outbreaks --> what's another approach?
#     - The SQL 'like' operator
#     - Summary, what is causing what here?
#
#  * possible error in [36]? should there be a graph here?
#  * it's a little fuzzy in the logic, may need more explanation step by step
#  * what is the Out[40] graph?
#
# Notebok 5: Clustering the news with Spark and MLLib
#     - Categorizing the news: text processing + machine learning
#     - k-means clustering, brief overview of supervised vs. unsupervised machine learning techniques, importance of clustering
#     - Scala Case Class?
#     - JSON4s? Read operation with type
#     - How to get numeric vectors out of words (word2vec)
#     - Building a stand-alone application
#     - Follow-up questions, summary of machine learning techniques with Big Data
#
#  * this notebook needs graphs??
#  * why randomly talk about a stand-alone application here? this should be a separate, supplementary notebook with more meat or more suggestions for future work
#  * the material in this notebook is already difficult, we probably won't have time to cover the stand-alone part sufficiently
#
# Notebook 6: Collecting Streaming News with Flume and Spark Streaming
#     - How do we keep up with news happening in real time?
#     - Explanation of a "stream" of data
#     - End-to-end stream processing system, Reuters news wire
#     - Collecting RSS data in python
#     - Apache Flume -- distributed data transfer system
#     - Spark streaming, spark applications, value of processing incoming data in real time (how is this different from analyzing historical data?)
#
#         - E-Tag data, high-water mark for news we've seen
#         - Source, channel, sink
#         - Using Spark Streaming to Search Streams
#             - processs the JSON records, keep track of how many articles we've seen, and write any articles about the flu to disk for later use
#             - If we've found flu data, we want to write it to HDFS --> how do we know we've found flu data?
#
#     - Providing libraries in a JAR file
#     - Summary of end-to-end pipeline that can monitor the news
#     - Follow-up projects: Add some of the machine learning approaches we applied to clustering the news to the streaming case. Could we detect a flu outbreak as it's happening?
#
#  * should we cut down the output In[52]?

# %% [markdown]
# Conclusion:
#     - Restate purpose of the workshop
#     - Who we are
#     - Where to learn more, how to ask questions, social media, etc.
#
#  * How are we going to handle ours/Oracle's affiliation with this project?

# %% [markdown]
# FAQ's
#     - Should we have a list of all the developer/data tools we use with links to their documentation ('for more information')
#     - How to contact us/report bugs
#     - Where'd we get our data?
#     - Suggested follow-up projects
#     - Github repo, video links
